# %% [markdown]
# # Simulated Annealing

# %% [markdown]
# ## Problem Description
#
# Perfrom analysis, design, and implementation of the **_Simulated Annealing_** (SA) algorithm into a computer program to find the **minimum value** of the function:

# %% [markdown]
# $$ f(x_1, x_2) = -\biggl( \sin{(x_1)} \cos{(x_2)} + {\frac{4}{5}} \exp {\biggl(1-\sqrt{x_1^2 + x_2^2}\biggr)} \biggr) $$
#
# with the limits $-10 \leq x_1 \leq 10 $ and $-10 \leq x_2 \leq 10$

# %%
import math
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Objective Function

# %%
def f(x1, x2):
    return -(
        math.sin(x1) * math.cos(x2) + (4/5) * 
        math.exp(1 - math.sqrt(x1**2 + x2**2))
    )

# %% [markdown]
# ## Visualizing the Function

# %%
i1 = np.arange(-10, 10, 0.01)
i2 = np.arange(-10, 10, 0.01)

x1m, x2m = np.meshgrid(i1, i2)
fm = np.zeros(x1m.shape)

for i in range(x1m.shape[0]):
    for j in range(x1m.shape[1]):
        fm[i][j] = f(x1m[i][j], x2m[i][j])

plt.figure(figsize=(20, 10))
plt.contourf(x1m, x2m, fm, cmap='afmhot')
plt.title('Function Visualization')
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar()

plt.show()

# %% [markdown]
# ## Generate State

# %%
def generate():
    # Initiating random floating number
    return random.uniform(-10, 10)

# %% [markdown]
# ## Acceptance Probability

# %%
def acceptance_probability(delta_E, T):
    # Calculate the acceptence probability for accepting new x1 & x2
    return math.exp(-(delta_E) / T)

# %% [markdown]
# ## Main Function

# %%
# Main function of the simulated annealing algorithm
def simulated_annealing(x1, x2, T):
    
    # Making an array to store the result history
    x1_history = []
    x2_history = []
    E_history = []
    
    # Initiating current best solution
    x1_best = x1
    x2_best = x2
    E = E_best = f(x1, x2)
    
    # Initiating iterations for check how long the loop
    i = 1
    
    # Loop until temperature decreased to given value
    while T > 0.1:
        # Generate new solution
        x1_new = x1 * generate()/math.exp(T)
        x2_new = x2 * generate()/math.exp(T)
        
        # Calculate new cost
        E_new = f(x1, x2)
        delta_E = E_new - E
        
        # If the new solution is better than current solution
        if (delta_E <= 0):
            x1 = x1_new
            x2 = x2_new
            E = E_new
            
            # Check wether the new solution is the current best best solution
            if (E_new < E_best):
                x1_best = x1_new
                x2_best = x2_new
                E_best = E_new
        
        # if the new solution is worse than the current solution
        else:
            p = acceptance_probability(delta_E, T)
            r = random.uniform(0, 1)
            
            if (r < p):
                x1 = x1_new
                x2 = x2_new
                E = E_new
        
        # Add the current solution to history array
        x1_history.append(x1_best)
        x2_history.append(x2_best)
        E_history.append(E_best)
        
        # Print the value of the current solution
        print("Iteration:",i)
        print("T: ", T, " E: ", E_best, " x1: ", x1_best, " x2: ", x2_best)
        print()
        
        # Increment for iterations
        i+=1
        
        # Annealing Schedule
        # Decrase the temperature with alpha value = 0.9
        T*=0.9
    
    # Print the result
    print("Best Solution: ", x1, ", ", x2)
    print("Best Objective: ", E)
    
    return x1_history, x2_history, E_history

# %% [markdown]
# ## Running the Algorithm

# %%
# Initianting temperature
T = 100

# Initiating the value of current value
# Generate state from random value (-10, 10)
x1 = generate()
x2 = generate()

x, y, E = simulated_annealing(x1, x2, T)
# Out:
# Iteration: 1
# T:  100  E:  -0.07673670221154319  x1:  9.515797289431443  x2:  9.990461856132097
#
# Iteration: 2
# T:  90.0  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 3
# T:  81.0  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 4
# T:  72.9  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 5
# T:  65.61000000000001  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 6
# T:  59.049000000000014  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 7
# T:  53.144100000000016  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 8
# T:  47.829690000000014  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 9
# T:  43.04672100000001  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 10
# T:  38.742048900000015  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 11
# T:  34.86784401000001  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 12
# T:  31.381059609000012  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 13
# T:  28.242953648100013  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 14
# T:  25.41865828329001  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 15
# T:  22.87679245496101  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 16
# T:  20.58911320946491  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 17
# T:  18.53020188851842  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 18
# T:  16.67718169966658  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 19
# T:  15.009463529699921  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 20
# T:  13.50851717672993  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 21
# T:  12.157665459056936  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 22
# T:  10.941898913151244  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 23
# T:  9.847709021836119  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 24
# T:  8.862938119652506  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 25
# T:  7.9766443076872555  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 26
# T:  7.17897987691853  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 27
# T:  6.461081889226677  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 28
# T:  5.81497370030401  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 29
# T:  5.233476330273609  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 30
# T:  4.710128697246248  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 31
# T:  4.239115827521624  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 32
# T:  3.815204244769461  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 33
# T:  3.433683820292515  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 34
# T:  3.090315438263264  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 35
# T:  2.7812838944369376  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 36
# T:  2.5031555049932437  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 37
# T:  2.2528399544939193  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 38
# T:  2.0275559590445273  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 39
# T:  1.8248003631400747  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 40
# T:  1.6423203268260673  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 41
# T:  1.4780882941434605  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 42
# T:  1.3302794647291145  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 43
# T:  1.1972515182562031  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 44
# T:  1.0775263664305827  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 45
# T:  0.9697737297875245  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 46
# T:  0.8727963568087721  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 47
# T:  0.785516721127895  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 48
# T:  0.7069650490151055  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 49
# T:  0.6362685441135949  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 50
# T:  0.5726416897022354  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 51
# T:  0.5153775207320118  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 52
# T:  0.46383976865881066  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 53
# T:  0.4174557917929296  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 54
# T:  0.37571021261363663  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 55
# T:  0.338139191352273  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 56
# T:  0.3043252722170457  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 57
# T:  0.2738927449953411  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 58
# T:  0.246503470495807  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 59
# T:  0.22185312344622632  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 60
# T:  0.1996678111016037  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 61
# T:  0.17970102999144333  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 62
# T:  0.161730926992299  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 63
# T:  0.1455578342930691  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 64
# T:  0.13100205086376218  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 65
# T:  0.11790184577738597  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Iteration: 66
# T:  0.10611166119964738  E:  -2.1746254627672363  x1:  2.5286293500060473e-80  x2:  4.148739690096276e-81
#
# Best Solution:  -0.0 ,  0.0
# Best Objective:  -2.1746254627672363

# %% [markdown]
# ## Visualizing the Result History

# %%
i1 = np.arange(-10, 10, 0.01)
i2 = np.arange(-10, 10, 0.01)

x1m, x2m = np.meshgrid(i1, i2)
fm = np.zeros(x1m.shape)

for i in range(x1m.shape[0]):
    for j in range(x1m.shape[1]):
        fm[i][j] = f(x1m[i][j], x2m[i][j])

plt.figure(figsize=(20, 10))
plt.contourf(x1m, x2m, fm, cmap='afmhot')
plt.title('SA Visualization')
plt.xlabel(x1)
plt.ylabel(x2)
plt.plot(x, y, 'y-o', color='white')
plt.colorbar()

plt.show()

# %%
fig = plt.figure()

objective_diagram = fig.add_subplot(211)
objective_diagram.plot(E, 'r.-')
objective_diagram.legend(['Objective'])

f_diagram = fig.add_subplot(212)
f_diagram.plot(x, 'b.-')
f_diagram.plot(y, 'g--')
f_diagram.legend(['x1, x2'])

plt.show()
